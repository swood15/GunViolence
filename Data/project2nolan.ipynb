# %%
#dependencies
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import datetime
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
#read csv
data = pd.read_csv("GVA_data (1).csv")
# Out:
# /Users/nolanhatch/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning:
#
# Columns (3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
data.head()
# Out:
#    Year      Month  Population mass_shooting officer_involved home_invasion  \
# 0  2016   3/1/2016     1830929         False            False         False
# 1  2014   8/1/2014     1849467         False            False         False
# 2  2015   8/1/2015     1841996         False            False         False
# 3  2015   3/1/2015     1841996         False            False         False
# 4  2015  12/1/2015     1841996         False            False         False
#
#   armed_robbery accidental non-shooting shots_fired   ...    \
# 0         False      False        False        True   ...
# 1         False      False        False       False   ...
# 2         False      False        False        True   ...
# 3         False      False        False        True   ...
# 4         False      False         True       False   ...
#
#          participant_status                        participant_type  \
# 0     0::Unharmed, Arrested                      0::Subject-Suspect
# ...

# %%
#create new df with needed info
data2 = data[["Year", "Month", "total_casualties", "n_killed", "n_injured"]].copy()

# %%
#remove all zero casualty totals and make new index
data2 = data2[data2.total_casualties !=0]

data2 = data2.reset_index()

# %%
#drop old index column
data2 = data2.drop(columns=["index"])

# %%
data2.head()
# Out:
#    Year      Month  total_casualties  n_killed  n_injured
# 0  2015  12/1/2015                 1         1          0
# 1  2016   5/1/2016                 1         1          0
# 2  2016   1/1/2016                 1         1          0
# 3  2015   6/1/2015                 1         1          0
# 4  2015   3/1/2015                 1         1          0

# %%
#group graph by year 
yeargrouped = data2.groupby("Year")

# %%
yeargrouped.head()
# Out:
#       Year      Month  total_casualties  n_killed  n_injured
# 0     2015  12/1/2015                 1         1          0
# 1     2016   5/1/2016                 1         1          0
# 2     2016   1/1/2016                 1         1          0
# 3     2015   6/1/2015                 1         1          0
# 4     2015   3/1/2015                 1         1          0
# 5     2015  12/1/2015                 1         1          0
# 6     2014   4/1/2014                 1         1          0
# 7     2015  11/1/2015                 1         1          0
# 8     2016   6/1/2016                 1         1          0
# 9     2014   4/1/2014                 1         1          0
# 10    2014   4/1/2014                 1         1          0
# 12    2014   9/1/2014                 1         1          0
# 13    2014   6/1/2014                 1         1          0
# 15    2016   1/1/2016                 1         1          0
# ...

# %%
#count total number of each column
totals_df = yeargrouped["total_casualties", "n_killed", "n_injured"].sum()

# %%
totals_df
# Out:
#       total_casualties  n_killed  n_injured
# Year
# 2013              1296       317        979
# 2014             35559     12557      23002
# 2015             40451     13484      26967
# 2016             45646     15066      30580
# 2017             46214     15511      30703
# 2018              9704      3533       6171

# %%
totals_df = totals_df.reset_index()

# %%
#drop incomplete years 
totals_df = totals_df.drop([0, 5])

# %%
totals_df
# Out:
#    Year  total_casualties  n_killed  n_injured
# 1  2014             35559     12557      23002
# 2  2015             40451     13484      26967
# 3  2016             45646     15066      30580
# 4  2017             46214     15511      30703

# %%
#plotly graph
data = [
    go.Bar(
        x=totals_df['Year'], # assign x as the dataframe column 'x'
        y=totals_df['n_killed'],
        name='Number Killed'
    ),
    go.Bar(
        x=totals_df['Year'],
        y=totals_df['n_injured'],
        name='Number Injured'
    )

]

# %%
layout = go.Layout(
    
    barmode='stack',
    title='Casualty Comparison of Number Killed vs Number Injured',
    xaxis=dict(
        title='Year',
    ),
    yaxis=dict(
        title='Number of Casualties',
    )    

)

fig = go.Figure(data=data, layout=layout)

# %%
url = py.plot(data, filename='pandas-bar-chart-layout', auto_open = True)
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~nolan_h/0 or inside your plot.ly account where it is named 'pandas-bar-chart-layout'
